# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 import sys
#       8 # Добавляем текущую папку в путь поиска модулей
#       9 # Это нужно, чтобы Python нашёл папки tabs и utils
# ---> 10 sys.path.insert(0, os.path.dirname(os.path.abspath(__file__)))
#      12 # Импорт наших модулей
#      13 from tabs.create_tab import CreateTab
#
# NameError: name '__file__' is not defined
